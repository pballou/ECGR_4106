# %%
'''
Patrick Ballou
ID: 801130521
ECGR 4106
Homework 1
Problem 1
'''
# Out:
# '\nPatrick Ballou\nID: 801130521\nECGR 4106\nHomework 1\nProblem 1\n'

# %%
gpu_info = !nvidia-smi
gpu_info = '\n'.join(gpu_info)
if gpu_info.find('failed') >= 0:
  print('Not connected to a GPU')
else:
  print(gpu_info)
# Out:
# Mon Jan 22 23:20:19 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 537.79                 Driver Version: 537.79       CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                     TCC/WDDM  | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Quadro T2000                 WDDM  | 00000000:01:00.0  On |                  N/A |
# | N/A   44C    P8               6W /  60W |    637MiB /  4096MiB |      2%      Default |
# |                                         |                      |                  N/A |
# ...
